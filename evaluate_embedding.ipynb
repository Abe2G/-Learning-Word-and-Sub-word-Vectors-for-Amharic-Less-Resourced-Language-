# %%
import os,re

# %%
def normalize_char_level_missmatch(input_token):
    rep1=re.sub('[ሃኅኃሐሓኻ]','ሀ',input_token)
    rep2=re.sub('[ሑኁዅ]','ሁ',rep1)
    rep3=re.sub('[ኂሒኺ]','ሂ',rep2)
    rep4=re.sub('[ኌሔዄ]','ሄ',rep3)
    rep5=re.sub('[ሕኅ]','ህ',rep4)
    rep6=re.sub('[ኆሖኾ]','ሆ',rep5)
    rep7=re.sub('[ሠ]','ሰ',rep6)
    rep8=re.sub('[ሡ]','ሱ',rep7)
    rep9=re.sub('[ሢ]','ሲ',rep8)
    rep10=re.sub('[ሣ]','ሳ',rep9)
    rep11=re.sub('[ሤ]','ሴ',rep10)
    rep12=re.sub('[ሥ]','ስ',rep11)
    rep13=re.sub('[ሦ]','ሶ',rep12)
    rep14=re.sub('[ዓኣዐ]','አ',rep13)
    rep15=re.sub('[ዑ]','ኡ',rep14)
    rep16=re.sub('[ዒ]','ኢ',rep15)
    rep17=re.sub('[ዔ]','ኤ',rep16)
    rep18=re.sub('[ዕ]','እ',rep17)
    rep19=re.sub('[ዖ]','ኦ',rep18)
    rep20=re.sub('[ጸ]','ፀ',rep19)
    rep21=re.sub('[ጹ]','ፁ',rep20)
    rep22=re.sub('[ጺ]','ፂ',rep21)
    rep23=re.sub('[ጻ]','ፃ',rep22)
    rep24=re.sub('[ጼ]','ፄ',rep23)
    rep25=re.sub('[ጽ]','ፅ',rep24)
    rep26=re.sub('[ጾ]','ፆ',rep25)
    #Normalizing words with Labialized Amharic characters such as በልቱዋል or  በልቱአል to  በልቷል  
    rep27=re.sub('(ሉ[ዋአ])','ሏ',rep26)
    rep28=re.sub('(ሙ[ዋአ])','ሟ',rep27)
    rep29=re.sub('(ቱ[ዋአ])','ቷ',rep28)
    rep30=re.sub('(ሩ[ዋአ])','ሯ',rep29)
    rep31=re.sub('(ሱ[ዋአ])','ሷ',rep30)
    rep32=re.sub('(ሹ[ዋአ])','ሿ',rep31)
    rep33=re.sub('(ቁ[ዋአ])','ቋ',rep32)
    rep34=re.sub('(ቡ[ዋአ])','ቧ',rep33)
    rep35=re.sub('(ቹ[ዋአ])','ቿ',rep34)
    rep36=re.sub('(ሁ[ዋአ])','ኋ',rep35)
    rep37=re.sub('(ኑ[ዋአ])','ኗ',rep36)
    rep38=re.sub('(ኙ[ዋአ])','ኟ',rep37)
    rep39=re.sub('(ኩ[ዋአ])','ኳ',rep38)
    rep40=re.sub('(ዙ[ዋአ])','ዟ',rep39)
    rep41=re.sub('(ጉ[ዋአ])','ጓ',rep40)
    rep42=re.sub('(ደ[ዋአ])','ዷ',rep41)
    rep43=re.sub('(ጡ[ዋአ])','ጧ',rep42)
    rep44=re.sub('(ጩ[ዋአ])','ጯ',rep43)
    rep45=re.sub('(ጹ[ዋአ])','ጿ',rep44)
    rep46=re.sub('(ፉ[ዋአ])','ፏ',rep45)
    rep47=re.sub('[ቊ]','ቁ',rep46) #ቁ can be written as ቊ
    rep48=re.sub('[ኵ]','ኩ',rep47) #ኩ can be also written as ኵ  

    return rep48

# %%
analogy_data=open('am_analogy_formated.txt',encoding='utf-8')
analogy=[]
for line in analogy_data:
    analogy.append(normalize_char_level_missmatch(line).strip().split())

# %%
with open('am_analogy_prepared.txt','a+',encoding='utf-8') as analogy_file:
    for pairs in analogy:
        analogy_file.write('\t'.join(pairs)+'\n')

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors
model= KeyedVectors.load('Model/am_w2v_cbow_200D')

analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt')

# %%
analogy_scores
# Out:
# (0.18840579710144928,
#  [{'section': 'capital-common-countries',
#    'correct': [('ሎሜ', 'ቶጎ', 'አስመራ', 'ኤርትራ'),
#     ('ሎሜ', 'ቶጎ', 'ሄልሲንኪ', 'ፊንላንድ'),
#     ('ሎሜ', 'ቶጎ', 'ናይሮቢ', 'ኬንያ'),
#     ('ሎሜ', 'ቶጎ', 'ቶሮንቶ', 'ካናዳ'),
#     ('ሎሜ', 'ቶጎ', 'ፓሪስ', 'ፈረንሳይ'),
#     ('አልጀርስ', 'አልጀሪያ', 'ባንኮክ', 'ታይላንድ'),
#     ('በርሊን', 'የጀርመን', 'ካይሮ', 'የግብፅ'),
#     ('በርሊን', 'የጀርመን', 'ካይሮ', 'የግብፅ'),
#     ('ኢትዮጵያ', 'ብር', 'ካናዳ', 'ዶላር'),
#     ('ወንድ', 'አባት', 'ሴት', 'እናት'),
#     ('ወንድ', 'መምህር', 'ሴት', 'መምህርት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('ንጉስ', 'ንግስት', 'ሰውየው', 'ሴትየዋ'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ችግር', 'ችግሮች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ክፍል', 'ክፍሎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ክፍል', 'ክፍልን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
# ...

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors
model= KeyedVectors.load('Model/am_fasttext_sg_300D')

analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt')#,restrict_vocab=300000

# %%
analogy_scores

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors

# %%
model= KeyedVectors.load('Model/am_w2v_cbow_100D')

analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt')#
analogy_scores
# Out:
# (0.15942028985507245,
#  [{'section': 'capital-common-countries',
#    'correct': [('ሎሜ', 'ቶጎ', 'ናይሮቢ', 'ኬንያ'),
#     ('ሎሜ', 'ቶጎ', 'ፓሪስ', 'ፈረንሳይ'),
#     ('አልጀርስ', 'አልጀሪያ', 'ባንኮክ', 'ታይላንድ'),
#     ('በርሊን', 'የጀርመን', 'አንካራ', 'የቱርክ'),
#     ('ወንድ', 'አባት', 'ሴት', 'እናት'),
#     ('ወንድ', 'መምህር', 'ሴት', 'መምህርት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('ንጉስ', 'ንግስት', 'ሰውየው', 'ሴትየዋ'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ችግር', 'ችግሮች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ክፍል', 'ክፍሎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ደብዳቤ', 'ደብዳቤዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('እናት', 'እናቶች', 'ሰው', 'ሰዎች'),
#     ('ምስራቅ', 'ምእራብ', 'ሰሜን', 'ደቡብ'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ትግሬ', 'ትግርኛ'),
#     ('በላ', 'ሲበላ', 'መጣ', 'ሲመጣ'),
#     ('በላ', 'ሲበላ', 'ሄደ', 'ሲሄድ'),
#     ('ወጣ', 'የወጣ', 'ቆመ', 'የቆመ'),
# ...

# %%
model= KeyedVectors.load('Model/10_sample_am_w2v_cbow_300D')
analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt')#
analogy_scores
# Out:
# (0.13526570048309178,
#  [{'section': 'capital-common-countries',
#    'correct': [('ሎሜ', 'ቶጎ', 'አስመራ', 'ኤርትራ'),
#     ('ሎሜ', 'ቶጎ', 'ናይሮቢ', 'ኬንያ'),
#     ('አልጀርስ', 'አልጀሪያ', 'ባንኮክ', 'ታይላንድ'),
#     ('በርሊን', 'የጀርመን', 'ካይሮ', 'የግብፅ'),
#     ('በርሊን', 'የጀርመን', 'አክራ', 'የጋና'),
#     ('በርሊን', 'የጀርመን', 'ካይሮ', 'የግብፅ'),
#     ('በርሊን', 'የጀርመን', 'አንካራ', 'የቱርክ'),
#     ('ወንድ', 'አባት', 'ሴት', 'እናት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('ወንድ', 'አጎት', 'ሴት', 'አክስት'),
#     ('እሱ', 'የእርሱ', 'እሷ', 'የእርሷ'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ችግር', 'ችግሮች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ክፍል', 'ክፍሎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ክፍል', 'ክፍልን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('መጠጥ', 'መጠጣት', 'ምግብ', 'መመገብ'),
#     ('ውሳኔ', 'መወሰን', 'ስራ', 'መስራት'),
#     ('አማራ', 'የአማራ', 'ኦሮሞ', 'የኦሮሞ'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ትግሬ', 'ትግርኛ'),
#     ('በላ', 'ሲበላ', 'ጠጣ', 'ሲጠጣ'),
# ...

# %%
model= KeyedVectors.load('Model/5w_10ng_am_w2v_cbow_200D')
analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt')#
analogy_scores
# Out:
# (0.1932367149758454,
#  [{'section': 'capital-common-countries',
#    'correct': [('ሎሜ', 'ቶጎ', 'አስመራ', 'ኤርትራ'),
#     ('ሎሜ', 'ቶጎ', 'ሄልሲንኪ', 'ፊንላንድ'),
#     ('ሎሜ', 'ቶጎ', 'ናይሮቢ', 'ኬንያ'),
#     ('አልጀርስ', 'አልጀሪያ', 'ኦስሎ', 'ኖርዌይ'),
#     ('በርሊን', 'የጀርመን', 'ካይሮ', 'የግብፅ'),
#     ('በርሊን', 'የጀርመን', 'ካይሮ', 'የግብፅ'),
#     ('ኢትዮጵያ', 'ብር', 'ካናዳ', 'ዶላር'),
#     ('ወንድ', 'ንጉስ', 'ሴት', 'ንግስት'),
#     ('ወንድ', 'አባት', 'ሴት', 'እናት'),
#     ('ወንድ', 'መምህር', 'ሴት', 'መምህርት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ችግር', 'ችግሮች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ክፍል', 'ክፍሎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ክፍል', 'ክፍልን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('ምርት', 'ምርታማነት', 'ውጤት', 'ውጤታማነት'),
#     ('እናት', 'እናቶች', 'ሰው', 'ሰዎች'),
# ...

# %%
#sample_am_fasttext_sg_200D
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors
model= KeyedVectors.load('Model/sample_am_fasttext_sg_200D')
analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt')#
analogy_scores
# Out:
# C:\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# (0.12077294685990338,
#  [{'section': 'capital-common-countries',
#    'correct': [('ሎሜ', 'ቶጎ', 'ናይሮቢ', 'ኬንያ'),
#     ('ሎሜ', 'ቶጎ', 'ቶሮንቶ', 'ካናዳ'),
#     ('በርሊን', 'የጀርመን', 'ሊብረቪል', 'የጋቦን'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ችግር', 'ችግሮች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ክፍል', 'ክፍሎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ደብዳቤ', 'ደብዳቤን'),
#     ('መጠጥ', 'መጠጣት', 'ምግብ', 'መመገብ'),
#     ('መጠጥ', 'መጠጣት', 'ጉዞ', 'መጓዝ'),
#     ('ውሳኔ', 'መወሰን', 'ስራ', 'መስራት'),
#     ('ምስራቅ', 'ምእራብ', 'ሰሜን', 'ደቡብ'),
#     ('ኦርቶዶክስ', 'ኦርቶዶክሳዊያን', 'ካናዳ', 'ካናዳዊያን'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ትግሬ', 'ትግርኛ'),
#     ('በላ', 'ሲበላ', 'ሄደ', 'ሲሄድ'),
#     ('በላ', 'ሲበላ', 'ወጣ', 'ሲወጣ'),
#     ('በላ', 'እየበላ', 'ሰበረ', 'እየሰበረ'),
# ...

# %%
#sample_am_fasttext_sg_200D
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors
model= KeyedVectors.load('Model/am_fasttext_cbow_100D')
analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt',restrict_vocab=100000)#
analogy_scores
# Out:
# (0.21951219512195122,
#  [{'section': 'capital-common-countries',
#    'correct': [('ወንድ', 'አባት', 'ሴት', 'እናት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('እሱ', 'የእርሱ', 'እሷ', 'የእርሷ'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ክፍል', 'ክፍልን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ደብዳቤ', 'ደብዳቤን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('ገደለ', 'ተገደለ', 'ሰማ', 'ተሰማ'),
#     ('መጠጥ', 'መጠጣት', 'ምግብ', 'መመገብ'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ጀርመን', 'ጀርመንኛ'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ትግሬ', 'ትግርኛ'),
#     ('በላ', 'ሲበላ', 'ጠጣ', 'ሲጠጣ'),
#     ('በላ', 'ሲበላ', 'መጣ', 'ሲመጣ'),
#     ('በላ', 'ሲበላ', 'ሄደ', 'ሲሄድ'),
#     ('በላ', 'እየበላ', 'ሄደ', 'እየሄደ'),
#     ('በላ', 'እየበላ', 'ጠጣ', 'እየጠጣ'),
#     ('በላ', 'እየበላ', 'መጣ', 'እየመጣ'),
#     ('በላ', 'እየበላ', 'ሰበሰበ', 'እየሰበሰበ'),
#     ('ወጣ', 'የወጣ', 'ተበላ', 'የተበላ'),
# ...

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors
model= KeyedVectors.load('Model/am_fasttext_cbow_200D')
analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt',restrict_vocab=100000)#
analogy_scores
# Out:
# (0.23780487804878048,
#  [{'section': 'capital-common-countries',
#    'correct': [('ወንድ', 'አባት', 'ሴት', 'እናት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('እሱ', 'የእርሱ', 'እሷ', 'የእርሷ'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ክፍል', 'ክፍልን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ደብዳቤ', 'ደብዳቤን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ጀርመን', 'ጀርመንኛ'),
#     ('ኦሮሞ', 'ኦሮምኛ', 'ትግሬ', 'ትግርኛ'),
#     ('በላ', 'ሲበላ', 'ጠጣ', 'ሲጠጣ'),
#     ('በላ', 'ሲበላ', 'መጣ', 'ሲመጣ'),
#     ('በላ', 'ሲበላ', 'ሄደ', 'ሲሄድ'),
#     ('በላ', 'ሲበላ', 'ወጣ', 'ሲወጣ'),
#     ('በላ', 'እየበላ', 'ወጣ', 'እየወጣ'),
#     ('በላ', 'እየበላ', 'ቆመ', 'እየቆመ'),
#     ('በላ', 'እየበላ', 'ሄደ', 'እየሄደ'),
#     ('በላ', 'እየበላ', 'ጠጣ', 'እየጠጣ'),
#     ('በላ', 'እየበላ', 'መጣ', 'እየመጣ'),
#     ('በላ', 'እየበላ', 'ሰበሰበ', 'እየሰበሰበ'),
# ...

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
from gensim.models import Word2Vec,KeyedVectors
model= KeyedVectors.load('Model/am_fasttext_sg_300D')
analogy_scores = model.wv.evaluate_word_analogies('am_analogy_prepared.txt',restrict_vocab=100000)#
analogy_scores
# Out:
# (0.14634146341463414,
#  [{'section': 'capital-common-countries',
#    'correct': [('ወንድ', 'መምህር', 'ሴት', 'መምህርት'),
#     ('ወንድ', 'ወንድም', 'ሴት', 'እህት'),
#     ('ወንዶች', 'ወንድሞች', 'ሴቶች', 'እህቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ችግር', 'ችግሮች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ክፍል', 'ክፍሎች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ምርት', 'ምርቶች'),
#     ('አገልግሎት', 'አገልግሎቶች', 'ስልጠና', 'ስልጠናዎች'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ክፍል', 'ክፍልን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ምርት', 'ምርትን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ደብዳቤ', 'ደብዳቤን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ስራ', 'ስራን'),
#     ('አገልግሎት', 'አገልግሎትን', 'ችግር', 'ችግርን'),
#     ('መጠጥ', 'መጠጣት', 'ምግብ', 'መመገብ'),
#     ('በላ', 'ሲበላ', 'ጠጣ', 'ሲጠጣ'),
#     ('ወጣ', 'የወጣ', 'ሰበረ', 'የሰበረ'),
#     ('ወጣ', 'የወጣ', 'ሄደ', 'የሄደ'),
#     ('ወጣ', 'የወጣ', 'መጣ', 'የመጣ'),
#     ('ወጣ', 'የወጣ', 'ወሰደ', 'የወሰደ'),
#     ('ሰው', 'ሰዎች', 'ልጅ', 'ልጆች'),
#     ('ሰው', 'ሰዎች', 'ህዝብ', 'ህዝቦች'),
#     ('ሰው', 'ሰዎች', 'እቃ', 'እቃዎች'),
#     ('መጠጣት', 'አለመጠጣት', 'መስራት', 'አለመስራት'),
# ...
